# %% [markdown]
# #Statistics and trends assignment

# %%
#import the relevant libraries
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt

# %%
#import the dataset
df = pd.read_csv("Worldbank_data.csv")

# %%
df.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    9/16/2022
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                  Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 0                                       NaN                NaN         NaN
# 1                                       NaN                NaN         NaN
# 2                                       NaN                NaN         NaN
# 3                            Indicator Name     Indicator Code    1960.000
# 4  Urban population (% of total population)  SP.URB.TOTL.IN.ZS      50.776
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
#drop the first 3 rows only
df1 =df.iloc[3:]

# %%
df1.head()
# Out:
#     Data Source World Development Indicators  \
# 3  Country Name                 Country Code
# 4         Aruba                          ABW
# 5         Aruba                          ABW
# 6         Aruba                          ABW
# 7         Aruba                          ABW
#
#                                  Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 3                            Indicator Name     Indicator Code    1960.000
# 4  Urban population (% of total population)  SP.URB.TOTL.IN.ZS      50.776
# 5                          Urban population        SP.URB.TOTL   27525.000
# 6        Urban population growth (annual %)        SP.URB.GROW         NaN
# 7                         Population, total        SP.POP.TOTL   54208.000
#
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8   Unnamed: 9  ...  \
# 3   1961.000000   1962.000000   1963.000000   1964.000000   1965.00000  ...
# 4     50.761000     50.746000     50.730000     50.715000     50.70000  ...
# ...

# %%
#making the text in row 3 the column header
df1.columns=df.iloc[3]

# %%
df1.head()
# Out:
# 3  Country Name  Country Code                            Indicator Name  \
# 3  Country Name  Country Code                            Indicator Name
# 4         Aruba           ABW  Urban population (% of total population)
# 5         Aruba           ABW                          Urban population
# 6         Aruba           ABW        Urban population growth (annual %)
# 7         Aruba           ABW                         Population, total
#
# 3     Indicator Code     1960.0        1961.0        1962.0        1963.0  \
# 3     Indicator Code   1960.000   1961.000000   1962.000000   1963.000000
# 4  SP.URB.TOTL.IN.ZS     50.776     50.761000     50.746000     50.730000
# 5        SP.URB.TOTL  27525.000  28139.000000  28537.000000  28763.000000
# 6        SP.URB.GROW        NaN      2.206183      1.404498      0.788835
# 7        SP.POP.TOTL  54208.000  55434.000000  56234.000000  56699.000000
#
# 3        1964.0       1965.0  ...         2012.0         2013.0  \
# ...

# %%
#drop row 3 in the dataframe
df2 =df1.drop([3])
df2.head()
# Out:
# 3 Country Name Country Code                            Indicator Name  \
# 4        Aruba          ABW  Urban population (% of total population)
# 5        Aruba          ABW                          Urban population
# 6        Aruba          ABW        Urban population growth (annual %)
# 7        Aruba          ABW                         Population, total
# 8        Aruba          ABW              Population growth (annual %)
#
# 3     Indicator Code     1960.0        1961.0        1962.0        1963.0  \
# 4  SP.URB.TOTL.IN.ZS     50.776     50.761000     50.746000     50.730000
# 5        SP.URB.TOTL  27525.000  28139.000000  28537.000000  28763.000000
# 6        SP.URB.GROW        NaN      2.206183      1.404498      0.788835
# 7        SP.POP.TOTL  54208.000  55434.000000  56234.000000  56699.000000
# 8        SP.POP.GROW        NaN      2.236462      1.432843      0.823502
#
# 3        1964.0        1965.0  ...         2012.0         2013.0  \
# ...

# %%
#drop indicator code column
df2.drop(["Indicator Code"],axis=1)
# Out:
# 3     Country Name Country Code  \
# 4            Aruba          ABW
# 5            Aruba          ABW
# 6            Aruba          ABW
# 7            Aruba          ABW
# 8            Aruba          ABW
# ...            ...          ...
# 20215     Zimbabwe          ZWE
# 20216     Zimbabwe          ZWE
# 20217     Zimbabwe          ZWE
# 20218     Zimbabwe          ZWE
# 20219     Zimbabwe          ZWE
#
# 3                                         Indicator Name     1960.0  \
# 4               Urban population (% of total population)     50.776
# 5                                       Urban population  27525.000
# 6                     Urban population growth (annual %)        NaN
# 7                                      Population, total  54208.000
# 8                           Population growth (annual %)        NaN
# ...                                                  ...        ...
# 20215  Rural land area where elevation is below 5 met...        NaN
# ...
