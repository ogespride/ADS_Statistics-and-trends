# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def classwork(filename):
    directory="C:/Users/DELL LATITUDE E7470/Desktop/UHMsc Data Science/Applied Data Science/"
    data=directory+filename
    df=pd.read_excel(data)
    return df,df.transpose()

classwork("Worldbank_data.xls")
# Out:
# (             Data Source World Development Indicators  \
#  0      Last Updated Date          2022-09-16 00:00:00
#  1                    NaN                          NaN
#  2           Country Name                 Country Code
#  3                  Aruba                          ABW
#  4                  Aruba                          ABW
#  ...                  ...                          ...
#  20214           Zimbabwe                          ZWE
#  20215           Zimbabwe                          ZWE
#  20216           Zimbabwe                          ZWE
#  20217           Zimbabwe                          ZWE
#  20218           Zimbabwe                          ZWE
#
#                                                Unnamed: 2         Unnamed: 3  \
#  0                                                    NaN                NaN
#  1                                                    NaN                NaN
# ...
